# %%
import pandas as pd
import geopandas as gpd
import zipfile
import requests
import os

# %%
import os
import requests
import geopandas as gpd
import pandas as pd

# -----------------------------
# Helper: download a file
# -----------------------------
def download_file(url, dest):
    """Download a file from GitHub Raw to dest."""
    r = requests.get(url)
    r.raise_for_status()
    with open(dest, "wb") as f:
        f.write(r.content)
    print(f"Downloaded → {dest}")

# -----------------------------
# Set up directories
# -----------------------------
raw_dir = "data/raw"
os.makedirs(raw_dir, exist_ok=True)

# GitHub raw URLs for flat files (CSV + GeoJSON)
files = {
    "parks": "parks_rec_2025.csv",
    "private_schools": "private_schools.geojson",
    "public_schools": "public_schools.geojson",
}

base_url = "https://raw.githubusercontent.com/daniimurphy/cyplan101-proj-group26/main/data/raw/"

# -----------------------------
# 1. Download all files
# -----------------------------
for key, fname in files.items():
    download_file(base_url + fname, f"{raw_dir}/{fname}")

# -----------------------------
# 2. Load datasets
# -----------------------------

# Parks CSV
parks = pd.read_csv(f"{raw_dir}/parks_rec_2025.csv")
print("Loaded parks_rec_2025.csv")

# Private schools GeoJSON
private_schools = gpd.read_file(f"{raw_dir}/private_schools.geojson")
print("Loaded private_schools.geojson")

# Public schools GeoJSON (direct load, no ZIP)
public_schools = gpd.read_file(f"{raw_dir}/public_schools.geojson")
print("Loaded public_schools.geojson")

# -----------------------------
# Final output
# -----------------------------
print("\n--- Data Loaded Successfully! ---")
print("parks:", parks.shape)
print("private_schools:", private_schools.shape)
print("public_schools:", public_schools.shape)

parks.head(), private_schools.head(), public_schools.head()
# Out:
# Downloaded → data/raw/parks_rec_2025.csv
# Downloaded → data/raw/private_schools.geojson
# Downloaded → data/raw/public_schools.geojson
# Loaded parks_rec_2025.csv
# Loaded private_schools.geojson
# Loaded public_schools.geojson
#
# --- Data Loaded Successfully! ---
# parks: (245, 31)
# private_schools: (40, 31)
# public_schools: (103165, 33)
# (   objectid  property_id                 property_name   longitude   latitude  \
#  0         1       137671               Herz Playground -122.416596  37.713505
#  1         4        11559                     City Hall -122.419265  37.779142
#  2         5        11476         Merced Branch Library -122.474494  37.726617
#  3         6        11485    Presidio Library Mini Park -122.444862  37.788930
#  4         7        11469  Eureka Valley Branch Library -122.431975  37.764014
#
#        acres        squarefeet perimeterlength  \
#  0  6.996710  304,777.90557355  2,274.17989609
#  1  0.806527   35,132.44912699  3,580.65596613
#  2  0.307695   13,403.26170521    467.90930349
#  3  0.678721   29,565.20733137  1,118.66905103
#  4  0.431479   18,795.31234328    548.38392562
#
#                        propertytype                      address  ...  \
#  0  Neighborhood Park or Playground          1701 Visitacion Ave  ...
#  1          Other Non-Park Property  1 Carlton B. Goodlett Place  ...
#  2                          Library            155 Winston Drive  ...
#  3                          Library           3150 Sacramento St  ...
#  4  Neighborhood Park or Playground                 3555 16th St  ...
#
#    police_district us_congress             realtor_neighborhood state_assembly  \
#  0       INGLESIDE          12                Visitacion Valley             17
#  1        NORTHERN          12            Van Ness/Civic Center             17
#  2         TARAVAL          14                         Lakeside             19
#  3        RICHMOND          12                  Pacific Heights             19
#  4         MISSION          12  Eureka Valley / Dolores Heights             17
#
#     planning_neighborhood                                              shape  \
#  0      Visitacion Valley  MULTIPOLYGON (((-122.415415277 37.713436563, -...
#  1  Downtown/Civic Center  MULTIPOLYGON (((-122.419832521 37.779072713, -...
#  2              Lakeshore  MULTIPOLYGON (((-122.474472703 37.726793505, -...
#  3        Pacific Heights  MULTIPOLYGON (((-122.444616287 37.788874908, -...
#  4    Castro/Upper Market  MULTIPOLYGON (((-122.432192223 37.763811052, -...
#
#               created_date        last_edited_date              data_as_of  \
#  0  2013/05/24 01:57:32 AM  2025/02/06 11:04:14 AM  2025/02/06 11:04:14 AM
#  1  2013/05/24 01:57:32 AM  2025/02/06 11:04:14 AM  2025/02/06 11:04:14 AM
#  2  2013/05/24 01:57:32 AM  2025/02/25 10:38:13 AM  2025/02/25 10:38:13 AM
#  3  2013/05/24 01:57:32 AM  2025/02/25 10:38:16 AM  2025/02/25 10:38:16 AM
#  4  2013/05/24 01:57:32 AM  2025/10/29 02:18:13 PM  2025/10/29 02:18:13 PM
#
#             data_loaded_at
#  0  2025/11/30 08:07:09 PM
#  1  2025/11/30 08:07:09 PM
#  2  2025/11/30 08:07:09 PM
#  3  2025/11/30 08:07:09 PM
#  4  2025/11/30 08:07:09 PM
#
#  [5 rows x 31 columns],
#     FID    NCESID                                   NAME         ADDRESS  \
#  0  341  00072439  ECOLE NOTRE DAME DES VICTOIRES SCHOOL     659 PINE ST
#  1  342  00072461                 SCHOOL OF THE EPIPHANY   600 ITALY AVE
#  2  343  00072472            HOLY NAME ELEMENTARY SCHOOL   1560 40TH AVE
#  3  344  00072483                         ICA CRISTO REY    3625 24TH ST
#  4  345  00072508          ST JOHN THE EVANGELIST SCHOOL  925 CHENERY ST
#
#              CITY STATE    ZIP           ZIP4       TELEPHONE TYPE  ...  \
#  0  SAN FRANCISCO    CA  94108           3210  (415) 421-0069    1  ...
#  1  SAN FRANCISCO    CA  94112           3519  (415) 337-4030    1  ...
#  2  SAN FRANCISCO    CA  94122           3099  (415) 731-4077    1  ...
#  3  SAN FRANCISCO    CA  94110  NOT AVAILABLE  (415) 824-2052    1  ...
#  4  SAN FRANCISCO    CA  94131           2962  (415) 584-8383    1  ...
#
#        VAL_METHOD       VAL_DATE        WEBSITE LEVEL_ ENROLLMENT  ST_GRADE  \
#  0        IMAGERY  1275868800000  NOT AVAILABLE      1        258         3
#  1  IMAGERY/OTHER  1275868800000  NOT AVAILABLE      1        185         3
#  2  IMAGERY/OTHER  1262131200000  NOT AVAILABLE      1        344         2
#  3  IMAGERY/OTHER  1262131200000  NOT AVAILABLE      2        336        14
#  4  IMAGERY/OTHER  1710720000000  NOT AVAILABLE      1        138         3
#
#     END_GRADE FT_TEACHER     SHELTER_ID                               geometry
#  0         13         21  NOT AVAILABLE  POINT (-13626224.90835 4549958.54429)
#  1         13          9       10780967   POINT (-13629349.64639 4539344.0562)
#  2         13         35  NOT AVAILABLE  POINT (-13636513.05569 4545240.59739)
#  3         17         33  NOT AVAILABLE  POINT (-13628118.45291 4544422.56781)
#  4         13         13  NOT AVAILABLE  POINT (-13629731.27992 4542068.65493)
#
#  [5 rows x 31 columns],
#     FID        NCESID                               NAME              ADDRESS  \
#  0    1  010000500870          ALBERTVILLE MIDDLE SCHOOL    600 E ALABAMA AVE
#  1    2  010000500871            ALBERTVILLE HIGH SCHOOL     402 E MCCORD AVE
#  2    3  010000500879    ALBERTVILLE INTERMEDIATE SCHOOL   901 W MCKINNEY AVE
#  3    4  010000500889      ALBERTVILLE ELEMENTARY SCHOOL   145 WEST END DRIVE
#  4    5  010000501616  ALBERTVILLE KINDERGARTEN AND PREK  257 COUNTRY CLUB RD
#
#            CITY STATE    ZIP           ZIP4       TELEPHONE TYPE  ...  \
#  0  ALBERTVILLE    AL  35950  NOT AVAILABLE  (256) 878-2341    1  ...
#  1  ALBERTVILLE    AL  35950           2322  (256) 894-5000    1  ...
#  2  ALBERTVILLE    AL  35950           1300  (256) 878-7698    1  ...
#  3  ALBERTVILLE    AL  35950  NOT AVAILABLE  (256) 894-4822    1  ...
#  4  ALBERTVILLE    AL  35951           3927  (256) 878-7922    1  ...
#
#                      WEBSITE      LEVEL_ ENROLLMENT ST_GRADE END_GRADE  \
#  0  http://www.albertk12.org      MIDDLE        890       07        08
#  1  http://www.albertk12.org        HIGH       1712       09        12
#  2  http://www.albertk12.org      MIDDLE        874       05        06
#  3  http://www.albertk12.org  ELEMENTARY        874       03        04
#  4  http://www.albertk12.org  ELEMENTARY        606       PK        KG
#
#     DISTRICTID  FT_TEACHER     SHELTER_ID  \
#  0     0100005          45  NOT AVAILABLE
#  1     0100005          85  NOT AVAILABLE
#  2     0100005          43  NOT AVAILABLE
#  3     0100005          43  NOT AVAILABLE
#  4     0100005          26  NOT AVAILABLE
#
#                                 GlobalID                          geometry
#  0  749ea212-5f7f-4c87-b55f-9aa1ad3799a2  POINT (-9596423.399 4063796.244)
#  1  dbcd670e-c3ec-40ee-9631-22d1540ca68c  POINT (-9596280.158 4064070.533)
#  2  a39a6c61-4555-4127-bb03-b5aa0dd04688  POINT (-9597986.282 4065562.798)
#  3  48157dc6-a198-460e-8e71-2f551e064dbf  POINT (-9598169.737 4062857.281)
#  4  2c11a540-71ed-4495-9eab-19d4fd9ca098  POINT (-9594988.049 4067791.333)
#
#  [5 rows x 33 columns])

# %%
parks.head()
# Out:
#    objectid  property_id                 property_name   longitude   latitude  \
# 0         1       137671               Herz Playground -122.416596  37.713505
# 1         4        11559                     City Hall -122.419265  37.779142
# 2         5        11476         Merced Branch Library -122.474494  37.726617
# 3         6        11485    Presidio Library Mini Park -122.444862  37.788930
# 4         7        11469  Eureka Valley Branch Library -122.431975  37.764014
#
#       acres        squarefeet perimeterlength  \
# 0  6.996710  304,777.90557355  2,274.17989609
# 1  0.806527   35,132.44912699  3,580.65596613
# 2  0.307695   13,403.26170521    467.90930349
# 3  0.678721   29,565.20733137  1,118.66905103
# 4  0.431479   18,795.31234328    548.38392562
#
#                       propertytype                      address  ...  \
# 0  Neighborhood Park or Playground          1701 Visitacion Ave  ...
# 1          Other Non-Park Property  1 Carlton B. Goodlett Place  ...
# 2                          Library            155 Winston Drive  ...
# 3                          Library           3150 Sacramento St  ...
# 4  Neighborhood Park or Playground                 3555 16th St  ...
#
#   police_district us_congress             realtor_neighborhood state_assembly  \
# 0       INGLESIDE          12                Visitacion Valley             17
# 1        NORTHERN          12            Van Ness/Civic Center             17
# 2         TARAVAL          14                         Lakeside             19
# 3        RICHMOND          12                  Pacific Heights             19
# 4         MISSION          12  Eureka Valley / Dolores Heights             17
#
#    planning_neighborhood                                              shape  \
# 0      Visitacion Valley  MULTIPOLYGON (((-122.415415277 37.713436563, -...
# 1  Downtown/Civic Center  MULTIPOLYGON (((-122.419832521 37.779072713, -...
# 2              Lakeshore  MULTIPOLYGON (((-122.474472703 37.726793505, -...
# 3        Pacific Heights  MULTIPOLYGON (((-122.444616287 37.788874908, -...
# 4    Castro/Upper Market  MULTIPOLYGON (((-122.432192223 37.763811052, -...
#
#              created_date        last_edited_date              data_as_of  \
# 0  2013/05/24 01:57:32 AM  2025/02/06 11:04:14 AM  2025/02/06 11:04:14 AM
# 1  2013/05/24 01:57:32 AM  2025/02/06 11:04:14 AM  2025/02/06 11:04:14 AM
# 2  2013/05/24 01:57:32 AM  2025/02/25 10:38:13 AM  2025/02/25 10:38:13 AM
# 3  2013/05/24 01:57:32 AM  2025/02/25 10:38:16 AM  2025/02/25 10:38:16 AM
# 4  2013/05/24 01:57:32 AM  2025/10/29 02:18:13 PM  2025/10/29 02:18:13 PM
#
#            data_loaded_at
# 0  2025/11/30 08:07:09 PM
# 1  2025/11/30 08:07:09 PM
# 2  2025/11/30 08:07:09 PM
# 3  2025/11/30 08:07:09 PM
# 4  2025/11/30 08:07:09 PM
#
# [5 rows x 31 columns]

# %%
private_schools.head()
# Out:
#    FID    NCESID                                   NAME         ADDRESS  \
# 0  341  00072439  ECOLE NOTRE DAME DES VICTOIRES SCHOOL     659 PINE ST
# 1  342  00072461                 SCHOOL OF THE EPIPHANY   600 ITALY AVE
# 2  343  00072472            HOLY NAME ELEMENTARY SCHOOL   1560 40TH AVE
# 3  344  00072483                         ICA CRISTO REY    3625 24TH ST
# 4  345  00072508          ST JOHN THE EVANGELIST SCHOOL  925 CHENERY ST
#
#             CITY STATE    ZIP           ZIP4       TELEPHONE TYPE  ...  \
# 0  SAN FRANCISCO    CA  94108           3210  (415) 421-0069    1  ...
# 1  SAN FRANCISCO    CA  94112           3519  (415) 337-4030    1  ...
# 2  SAN FRANCISCO    CA  94122           3099  (415) 731-4077    1  ...
# 3  SAN FRANCISCO    CA  94110  NOT AVAILABLE  (415) 824-2052    1  ...
# 4  SAN FRANCISCO    CA  94131           2962  (415) 584-8383    1  ...
#
#       VAL_METHOD       VAL_DATE        WEBSITE LEVEL_ ENROLLMENT  ST_GRADE  \
# 0        IMAGERY  1275868800000  NOT AVAILABLE      1        258         3
# 1  IMAGERY/OTHER  1275868800000  NOT AVAILABLE      1        185         3
# 2  IMAGERY/OTHER  1262131200000  NOT AVAILABLE      1        344         2
# 3  IMAGERY/OTHER  1262131200000  NOT AVAILABLE      2        336        14
# 4  IMAGERY/OTHER  1710720000000  NOT AVAILABLE      1        138         3
#
#    END_GRADE FT_TEACHER     SHELTER_ID                               geometry
# 0         13         21  NOT AVAILABLE  POINT (-13626224.90835 4549958.54429)
# 1         13          9       10780967   POINT (-13629349.64639 4539344.0562)
# 2         13         35  NOT AVAILABLE  POINT (-13636513.05569 4545240.59739)
# 3         17         33  NOT AVAILABLE  POINT (-13628118.45291 4544422.56781)
# 4         13         13  NOT AVAILABLE  POINT (-13629731.27992 4542068.65493)
#
# [5 rows x 31 columns]

# %%
public_schools.head()
# Out:
#    FID        NCESID                               NAME              ADDRESS  \
# 0    1  010000500870          ALBERTVILLE MIDDLE SCHOOL    600 E ALABAMA AVE
# 1    2  010000500871            ALBERTVILLE HIGH SCHOOL     402 E MCCORD AVE
# 2    3  010000500879    ALBERTVILLE INTERMEDIATE SCHOOL   901 W MCKINNEY AVE
# 3    4  010000500889      ALBERTVILLE ELEMENTARY SCHOOL   145 WEST END DRIVE
# 4    5  010000501616  ALBERTVILLE KINDERGARTEN AND PREK  257 COUNTRY CLUB RD
#
#           CITY STATE    ZIP           ZIP4       TELEPHONE TYPE  ...  \
# 0  ALBERTVILLE    AL  35950  NOT AVAILABLE  (256) 878-2341    1  ...
# 1  ALBERTVILLE    AL  35950           2322  (256) 894-5000    1  ...
# 2  ALBERTVILLE    AL  35950           1300  (256) 878-7698    1  ...
# 3  ALBERTVILLE    AL  35950  NOT AVAILABLE  (256) 894-4822    1  ...
# 4  ALBERTVILLE    AL  35951           3927  (256) 878-7922    1  ...
#
#                     WEBSITE      LEVEL_ ENROLLMENT ST_GRADE END_GRADE  \
# 0  http://www.albertk12.org      MIDDLE        890       07        08
# 1  http://www.albertk12.org        HIGH       1712       09        12
# 2  http://www.albertk12.org      MIDDLE        874       05        06
# 3  http://www.albertk12.org  ELEMENTARY        874       03        04
# 4  http://www.albertk12.org  ELEMENTARY        606       PK        KG
#
#    DISTRICTID  FT_TEACHER     SHELTER_ID  \
# 0     0100005          45  NOT AVAILABLE
# 1     0100005          85  NOT AVAILABLE
# 2     0100005          43  NOT AVAILABLE
# 3     0100005          43  NOT AVAILABLE
# 4     0100005          26  NOT AVAILABLE
#
#                                GlobalID                          geometry
# 0  749ea212-5f7f-4c87-b55f-9aa1ad3799a2  POINT (-9596423.399 4063796.244)
# 1  dbcd670e-c3ec-40ee-9631-22d1540ca68c  POINT (-9596280.158 4064070.533)
# 2  a39a6c61-4555-4127-bb03-b5aa0dd04688  POINT (-9597986.282 4065562.798)
# 3  48157dc6-a198-460e-8e71-2f551e064dbf  POINT (-9598169.737 4062857.281)
# 4  2c11a540-71ed-4495-9eab-19d4fd9ca098  POINT (-9594988.049 4067791.333)
#
# [5 rows x 33 columns]

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import numpy as np

# ================================================================
# Helper - Convert records with geometry = {"x":..., "y":...} → GeoDataFrame
# ================================================================
def to_geodf_from_xy(df, xcol="x", ycol="y", geom_col="geometry", crs="EPSG:4326"):
    records = []
    for _, row in df.iterrows():
        attrs = row.to_dict()
        geom = attrs.pop(geom_col)
        point = Point(geom["x"], geom["y"])
        attrs["geometry"] = point
        records.append(attrs)

    return gpd.GeoDataFrame(records, geometry="geometry", crs=crs)


# ================================================================
# Helper - Standardize school level codes
# ================================================================
priv_level_map = {
    1: "Elementary",
    2: "High",
    3: "Combined"
}

pub_level_map = {
    "ELEMENTARY": "Elementary",
    "PREKINDERGARTEN": "Elementary",
    "MIDDLE": "Middle",
    "HIGH": "High",
    "SECONDARY": "Combined",
    "OTHER": "Combined",
    "UNGRADED": "Combined",
    "NOT REPORTED": None,
    "NOT APPLICABLE": None,
    "ADULT EDUCATION": None
}

def clean_level_private(df):
    return df["level_"].map(priv_level_map)

def clean_level_public(df):
    return df["level_"].str.upper().map(pub_level_map)


# ================================================================
# Helper - Filter to San Francisco city/county
# ================================================================
def filter_to_san_francisco(gdf):
    return gdf[
        gdf["city"].str.contains("San Francisco", case=False, na=False) |
        gdf["county"].str.contains("San Francisco", case=False, na=False)
    ]


# ================================================================
# Helper - Clean enrollment (negative → NaN)
# ================================================================
def clean_enrollment(df):
    df["enrollment"] = df["enrollment"].astype(float)
    df.loc[df["enrollment"] < 0, "enrollment"] = np.nan
    return df


# ================================================================
# MAIN PIPELINE
# ================================================================
def process_school_data(private_raw, public_raw):
    """
    private_raw: GeoDataFrame (private_schools)
    public_raw: GeoDataFrame (public_schools)

    The function cleans the raw private and public school datasets,
    returning a single dataset with all schools in SF.

    The process filters by selecting only schools in SF.
    Negative values in "enrollment" columns are converted to NaN,
    The school is assigned a new "level_clean" class of either
    elementary, middle, high, or other.

    The public and private schools are concatenated into a single dataset which is returned.
    """

    # --- Ensure both are GeoDataFrames with the same CRS ---
    if private_raw.crs is None:
        raise ValueError("private_raw has no CRS defined")
    if public_raw.crs is None:
        raise ValueError("public_raw has no CRS defined")

    private = private_raw.copy()
    public = public_raw.copy()

    # Convert everything to WGS84 BEFORE touching columns or concatenating
    private = private_raw.to_crs("EPSG:4326").copy()
    public  = public_raw.to_crs("EPSG:4326").copy()

    # ------------------------------------------------------------
    # Normalize column names
    # ------------------------------------------------------------


    # Both should use lowercase column names
    private.columns = private.columns.str.lower()
    public.columns = public.columns.str.lower()

    # ------------------------------------------------------------
    # Standardize level categories
    # ------------------------------------------------------------
    private["level_clean"] = clean_level_private(private)
    public["level_clean"] = clean_level_public(public)

    # ------------------------------------------------------------
    # Clean enrollment
    # ------------------------------------------------------------
    private = clean_enrollment(private)
    public = clean_enrollment(public)

    # ------------------------------------------------------------
    # Filter to San Francisco only
    # ------------------------------------------------------------
    private_sf = filter_to_san_francisco(private)
    public_sf = filter_to_san_francisco(public)

    # ------------------------------------------------------------
    # Harmonize schemas
    # ------------------------------------------------------------
    # Public has two extra cols we want to preserve:
    # DISTRICTID, GLOBALID (lowercase: districtid, globalid)
    needed_cols = sorted(set(private_sf.columns) | set(public_sf.columns))

    # Add missing columns to private
    for col in needed_cols:
        if col not in private_sf.columns:
            private_sf[col] = None

    # Add missing columns to public
    for col in needed_cols:
        if col not in public_sf.columns:
            public_sf[col] = None

    # Order columns consistently
    private_sf = private_sf[needed_cols]
    public_sf = public_sf[needed_cols]

    # ------------------------------------------------------------
    # Concatenate
    # ------------------------------------------------------------
    schools_sf = pd.concat([private_sf, public_sf], ignore_index=True)

    # ------------------------------------------------------------
    # Create unique school_id
    # ------------------------------------------------------------
    schools_sf["school_id"] = schools_sf.index.astype(int)

    # Ensure GeoDataFrame & CRS
    schools_sf = gpd.GeoDataFrame(schools_sf, geometry="geometry", crs="EPSG:4326")

    return schools_sf

# %%
private_schools.columns
# Out:
# Index(['FID', 'NCESID', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP', 'ZIP4',
#        'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY', 'COUNTYFIPS',
#        'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE', 'NAICS_DESC',
#        'SOURCE', 'SOURCE_DAT', 'VAL_METHOD', 'VAL_DATE', 'WEBSITE', 'LEVEL_',
#        'ENROLLMENT', 'ST_GRADE', 'END_GRADE', 'FT_TEACHER', 'SHELTER_ID',
#        'geometry'],
#       dtype='object')

# %%
# ================================================================
# 6. RUN PIPELINE
# ================================================================
# Example usage

schools_sf = process_school_data(private_schools, public_schools)
schools_sf.head()
# Out:
#           address           city country         county countyfips districtid  \
# 0     659 PINE ST  SAN FRANCISCO     USA  SAN FRANCISCO      07506       None
# 1   600 ITALY AVE  SAN FRANCISCO     USA  SAN FRANCISCO      07506       None
# 2   1560 40TH AVE  SAN FRANCISCO     USA  SAN FRANCISCO      07506       None
# 3    3625 24TH ST  SAN FRANCISCO     USA  SAN FRANCISCO      07506       None
# 4  925 CHENERY ST  SAN FRANCISCO     USA  SAN FRANCISCO      06075       None
#
#   end_grade  enrollment  fid  ft_teacher  ... state status       telephone  \
# 0        13       258.0  341          21  ...    CA      1  (415) 421-0069
# 1        13       185.0  342           9  ...    CA      1  (415) 337-4030
# 2        13       344.0  343          35  ...    CA      1  (415) 731-4077
# 3        17       336.0  344          33  ...    CA      1  (415) 824-2052
# 4        13       138.0  345          13  ...    CA      1  (415) 584-8383
#
#   type       val_date     val_method        website    zip           zip4  \
# 0    1  1275868800000        IMAGERY  NOT AVAILABLE  94108           3210
# 1    1  1275868800000  IMAGERY/OTHER  NOT AVAILABLE  94112           3519
# 2    1  1262131200000  IMAGERY/OTHER  NOT AVAILABLE  94122           3099
# 3    1  1262131200000  IMAGERY/OTHER  NOT AVAILABLE  94110  NOT AVAILABLE
# 4    1  1710720000000  IMAGERY/OTHER  NOT AVAILABLE  94131           2962
#
#   school_id
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
#
# [5 rows x 35 columns]
